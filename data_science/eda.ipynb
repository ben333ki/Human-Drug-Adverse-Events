# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd
from sqlalchemy import create_engine
from data_engineer.config import DB_USER, DB_PASSWORD, DB_HOST, DB_PORT, DB_NAME, TABLE_NAME

engine = create_engine(f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
df = pd.read_sql(f"SELECT * FROM {TABLE_NAME}", engine)

# ตรวจสอบ head, missing values, distribution
print(df.head())
print(df.info())
print(df['drug_name'].value_counts())
print(df['seriousness'].value_counts())
# Out:
#    patient_age  age_unit  sex drug_name  drug_route         reaction  \
# 0         32.0     801.0  2.0  ZEPBOUND         NaN  Nephrolithiasis
# 1         32.0     801.0  2.0  ZEPBOUND         NaN   Diverticulitis
# 2         32.0     801.0  2.0  ZEPBOUND         NaN    Feeling drunk
# 3         32.0     801.0  2.0  ZEPBOUND         NaN          Illness
# 4         32.0     801.0  2.0  ZEPBOUND         NaN             Pain
#
#    seriousness  receivedate
# 0            1     20170523
# 1            1     20170523
# 2            1     20170523
# 3            1     20170523
# 4            1     20170523
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305291 entries, 0 to 305290
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   patient_age  262788 non-null  float64
#  1   age_unit     262793 non-null  float64
#  2   sex          269792 non-null  float64
#  3   drug_name    305291 non-null  object
#  4   drug_route   265670 non-null  float64
#  5   reaction     305291 non-null  object
#  6   seriousness  305291 non-null  int64
#  7   receivedate  305291 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 18.6+ MB
# None
# drug_name
# ZEPBOUND       233472
# SEMAGLUTIDE     39076
# LIRAGLUTIDE     17737
# TIRZEPATIDE      9423
# DULAGLUTIDE      5583
# Name: count, dtype: int64
# seriousness
# 2    225953
# 1     79338
# Name: count, dtype: int64
