# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data_engineer/processed/glp1_features.csv")
print(df.columns)
# Out:
# Index(['age_years', 'sex_F', 'sex_M', 'sex_UNKNOWN', 'drug_name_DULAGLUTIDE',
#        'drug_name_LIRAGLUTIDE', 'drug_name_SEMAGLUTIDE',
#        'drug_name_TIRZEPATIDE', 'drug_name_ZEPBOUND', 'drug_route_23.0',
#        'drug_route_3.0', 'drug_route_30.0', 'drug_route_41.0',
#        'drug_route_42.0', 'drug_route_47.0', 'drug_route_48.0',
#        'drug_route_50.0', 'drug_route_51.0', 'drug_route_54.0',
#        'drug_route_55.0', 'drug_route_58.0', 'drug_route_59.0',
#        'drug_route_60.0', 'drug_route_61.0', 'drug_route_62.0',
#        'drug_route_64.0', 'drug_route_65.0', 'drug_route_UNKNOWN', 'label',
#        'seriousness'],
#       dtype='object')

# %%
import sys
import os
# ensure repo root is on sys.path so we can import data_engineer.config
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from sqlalchemy import create_engine
from data_engineer.config import DB_USER, DB_PASSWORD, DB_HOST, DB_PORT, DB_NAME, TABLE_NAME
# create engine using config values

engine = create_engine(f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
df_raw = pd.read_sql(f"SELECT sex FROM {TABLE_NAME}", engine)
print(df_raw["sex"].unique())

df_raw = pd.read_sql(f"SELECT seriousness FROM {TABLE_NAME}", engine)
print(df_raw["seriousness"].unique())

df_raw = pd.read_sql(f"SELECT age_unit FROM {TABLE_NAME}", engine)
print(df_raw["age_unit"].unique())
# Out:
# [ 2.  1. nan  0.]
# [1 2]
# [1 2]
# [801.  nan 804. 800. 802. 803.]
# [801.  nan 804. 800. 802. 803.]

# %%
df = pd.read_csv("../data_engineer/processed/glp1_clean.csv")
df.info()
df.head()
df["sex"].value_counts(dropna=False)
df["seriousness"].value_counts()
df["age_unit"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262553 entries, 0 to 262552
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   patient_age  262553 non-null  float64
#  1   age_unit     262553 non-null  object
#  2   sex          245956 non-null  object
#  3   drug_name    262553 non-null  object
#  4   drug_route   262553 non-null  object
#  5   reaction     262553 non-null  object
#  6   seriousness  262553 non-null  int64
#  7   receivedate  262553 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 16.0+ MB
# age_unit
# years      262274
# unknown       244
# months         12
# weeks          12
# days           11
# Name: count, dtype: int64

# %%
df["seriousness"].value_counts(normalize=True)
# Out:
# seriousness
# 0    0.750987
# 1    0.249013
# Name: proportion, dtype: float64
