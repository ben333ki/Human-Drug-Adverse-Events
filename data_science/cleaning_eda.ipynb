# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from data_engineer.config import GLP1_DRUGS

df = pd.read_csv("../data_engineer/raw/openfda_raw.csv")

df.head()
# Out:
#    patient_age  age_unit  sex drug_name  drug_route         reaction  \
# 0         32.0     801.0  2.0  ZEPBOUND         NaN  Nephrolithiasis
# 1         32.0     801.0  2.0  ZEPBOUND         NaN   Diverticulitis
# 2         32.0     801.0  2.0  ZEPBOUND         NaN    Feeling drunk
# 3         32.0     801.0  2.0  ZEPBOUND         NaN          Illness
# 4         32.0     801.0  2.0  ZEPBOUND         NaN             Pain
#
#    seriousness  receivedate
# 0            1     20170523
# 1            1     20170523
# 2            1     20170523
# 3            1     20170523
# 4            1     20170523
